# %%
import pandas as pd
import re


# Read the list of filenames from the configuration file
with open('../file_list.txt', 'r', encoding='utf-8') as config_file:
    file_names = config_file.read().splitlines()

# Regex pattern to match the data format
pattern = r'\[(.*?)\] (.*?): (.*)'

# Initialize an empty list to store parsed data
datalist = []
stream_count = 0
# Iterate over each specified file
for file in file_names:
    full_path = f"../data/{file}"
    with open(full_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines:
            match = re.match(pattern, line)
            if match:
                date, user, message = match.groups()
                datalist.append([date, user, message,stream_count])
    stream_count = stream_count + 1

# Create a DataFrame from the parsed data
data = pd.DataFrame(datalist, columns=["date", "user", "message","stream"])

# %%
data.shape
# Out:
# (992441, 4)

# %%
filteredData = data[data['user']=='StreamElements' ]
#klim = klim[klim['message'].str.split().str.len() >= 3]
filteredData = filteredData[filteredData['message'].str.contains('balintboss', case=False) & 
                            filteredData['message'].str.contains('spent', case=False)]

# %%
def has_word_more_than_three_times(message):
    words = message.split()  # Split the message into words
    word_counts = pd.Series(words).value_counts()  # Count occurrences of each word
    return any(word_counts > 10)  # Check if any word appears more than 3 times

# %%
# Apply the filter
#klim = klim[~klim['message'].apply(has_word_more_than_three_times)]

# %%
filteredData
# Out:
#                            date            user  \
# 22448   2024-05-10 17:07:20 UTC  StreamElements
# 39489   2024-05-18 15:18:03 UTC  StreamElements
# 88451   2024-06-03 18:58:46 UTC  StreamElements
# 134251  2024-06-18 13:31:25 UTC  StreamElements
# 161428  2024-07-06 12:39:33 UTC  StreamElements
# 176531  2024-07-12 17:29:50 UTC  StreamElements
# 204156  2024-07-24 13:18:08 UTC  StreamElements
# 248897  2024-08-07 12:06:02 UTC  StreamElements
# 316619  2024-09-04 16:32:40 UTC  StreamElements
# 384756  2024-09-22 12:17:07 UTC  StreamElements
# 415566  2024-10-03 15:10:35 UTC  StreamElements
# 459925  2024-10-15 13:02:22 UTC  StreamElements
# 593447  2024-11-14 16:34:05 UTC  StreamElements
# 593459  2024-11-14 16:34:31 UTC  StreamElements
# 639351  2024-11-28 14:22:40 UTC  StreamElements
# 677007  2024-12-07 17:06:32 UTC  StreamElements
# 744823  2024-12-20 14:47:12 UTC  StreamElements
# 756375  2024-12-22 17:31:30 UTC  StreamElements
# ...

# %%
#filteredData.to_csv('data.txt', sep='\t', index=False)

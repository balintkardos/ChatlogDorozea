# %%
import pandas as pd
import re
import pytz
import json

# %%
# --- 1. Load Data ---

# Load the file names
# Make sure 'file_list.txt' is in the same directory or provide the full path
try:
    with open('file_list.txt', 'r', encoding='utf-8') as config_file:
        file_names = config_file.read().splitlines()
except FileNotFoundError:
    print("Error: 'file_list.txt' not found. Please ensure it exists.")
    exit() # Exit if the file list is missing

# %%
# Regex pattern to match the log entries
pattern = r'\[(.*?)\] (.*?): (.*)'

datalist = []
stream_count = 0
# Assuming 'data' subdirectory exists relative to the script location
data_dir = "data\\"

for file in file_names:
    full_path = data_dir + file
    try:
        with open(full_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
            for line in lines:
                match = re.match(pattern, line)
                if match:
                    date_str, user, message = match.groups()
                    # Append raw data first, convert date later for efficiency
                    datalist.append([date_str, user, message, stream_count])
        stream_count += 1
    except FileNotFoundError:
        print(f"Warning: File '{full_path}' not found. Skipping.")
    except Exception as e:
        print(f"Error reading file '{full_path}': {e}")

# %%
# --- 2. Create DataFrame and Initial Processing ---

if not datalist:
    print("Error: No data was loaded. Exiting.")
    exit()

# Create a DataFrame
data = pd.DataFrame(datalist, columns=["date_str", "user", "message", "stream"])

# %%
# Convert 'date_str' to datetime format (handle potential errors)
data['date'] = pd.to_datetime(data['date_str'], errors='coerce')

# %%
def convert_utc_to_cet(df, date_column='date'):
    # Make a copy to avoid modifying the original
    df = df.copy()
    
    # Ensure timestamps are UTC aware
    if df[date_column].dt.tz is None:
        df[date_column] = df[date_column].dt.tz_localize('UTC')
    elif df[date_column].dt.tz != pytz.UTC:
        df[date_column] = df[date_column].dt.tz_convert('UTC')
    
    # Convert to CET/CEST (Europe/Berlin includes proper DST handling)
    df[date_column] = df[date_column].dt.tz_convert('Europe/Berlin')
    
    return df

# %%
data = convert_utc_to_cet(data)

# %%
# Drop rows where date conversion failed
original_rows = len(data)
data.dropna(subset=['date'], inplace=True)
if len(data) < original_rows:
    print(f"Warning: Dropped {original_rows - len(data)} rows due to invalid date format.")

# %%
# --- 3. User Replacements / Cleaning ---
# (Using .loc for potentially better performance on large datasets)
replace_map = {
    "Banties1g": "banties_x",
    "banties1g": "banties_x",
    "chili_poe": "chili_con_bacon",
    "CHILI_POE": "chili_con_bacon",
    "chili_conbacon": "chili_con_bacon",
    "Wirelesss_": "W1r3lesss",
    "treklul": "trek44_",
    "ttrek_": "trek44_",
    "TriplesingleJ": "TripleSingleJames",
    "uuccugr": "uwu_cougar",
    "uuccugr": "uuccugr_"
}
data["user"] = data["user"].replace(replace_map)

# %%
from collections import defaultdict

# Get all unique usernames
unique_users = data['user'].unique()

# Create a mapping from lowercase username to all variants

user_variants = defaultdict(set)
for user in unique_users:
    user_variants[user.lower()].add(user)

# Find usernames with different capitalization
duplicate_users = {k: v for k, v in user_variants.items() if len(v) > 1}

# Display the results
for lower, variants in duplicate_users.items():
    print(f"{lower}: {sorted(variants)}")
# Out:
# tilch: ['Tilch', 'tilch']
# gyllenc: ['Gyllenc', 'gyllenc']
# roomunder: ['ROOMUNDER', 'roomunder']
# notbat: ['NOTBAT', 'notbat']
# nurm1_0_0: ['NURM1_0_0', 'NuRM1_0_0']
# iamconvinc3d: ['Iamconvinc3d', 'iamconvinc3d']
# wisez__: ['wiseZ__', 'wisez__']
# r4rrixd: ['R4RRIXD', 'r4rrixd']
# obungakung: ['OBUNGAKUNG', 'obungakung']
# chimphailpk: ['ChimpHailpk', 'chimphailpk']
# xfrell1: ['Xfrell1', 'xfrell1']
# lopilop1: ['Lopilop1', 'lopilop1']
# trodainus: ['Trodainus', 'trodainus']
# kavnera: ['KAVNERA', 'kavnera']
# noxiex4charity12: ['Noxiex4Charity12', 'noxiex4charity12']
# macbless: ['MacBless', 'macbless']
# anos87w: ['Anos87w', 'anos87w']
# vladyslav_h: ['VLADYSLAV_H', 'vladyslav_h']
# ars_rugal: ['ARS_RUGAL', 'ars_rugal']
# artemioni4: ['Artemioni4', 'artemioni4']
# torst3ncs: ['tORST3NCS', 'tORST3Ncs']
# adel5244: ['Adel5244', 'adel5244']
# f1zzcsgo: ['F1ZZcsgo', 'f1zzcsgo']
# bubrekht: ['BuBRekht', 'BuBrekht', 'bubrekht']
# martimmendez: ['MartimMendeZ', 'martimmendez']
# xvenumz_97: ['xVeNuMz_97', 'xvenumz_97']
# alsobres2: ['AlSobreS2', 'alsobreS2']
# lazysloth4lyfez: ['LazySloth4Lyfez', 'Lazysloth4lyfez']
# sinazanjirchi: ['SinaZanjirchi', 'sinazanjirchi']
# omarmohamed3211: ['Omarmohamed3211', 'omarmohamed3211']
# fangho_: ['FanGho_', 'fangho_']
# laurencece: ['LaurenceCE', 'Laurencece']
# xisken: ['XISKEN', 'xisken']
# gamerunderall: ['GamerUnderAll', 'gamerunderall']
# thwaco: ['Thwaco', 'thwaco']
# mrxmorgan: ['MrxMorgan', 'mrxmorgan']
# courtneygenetti: ['CourtneyGenetti', 'courtneygenetti']
# iinezu: ['IiNezu', 'iiNezu']
# snufkingred: ['Snufkingred', 'snufkingred']
# supremeza: ['SupremeZa', 'supRemeza']
# metalism: ['Metalism', 'metalism']
# quanglick1: ['QuangLick1', 'quanglick1']
# katana_lt: ['KaTaNa_LT', 'KataNa_LT']
# gsk_lol: ['GSK_lol', 'gsk_lol']
# mrdursleyessence: ['MrDursleyEssence', 'mrdursleyessence']
# kukalfg: ['kukaLFG', 'kukalfg']
# crouchh: ['Crouchh', 'crouchh']
# waadulf: ['Waadulf', 'waadulf']
# itsssyugi: ['itsssYugi', 'itsssyugi']
# bhargav_pilli: ['Bhargav_Pilli', 'bhargav_pilli']
# onlyyfaisal: ['OnlyyFaisal', 'onlyyfaisal']
# realdrakkar: ['RealDrakkar', 'realdrakkar']
# morningstart12: ['MorningStarT12', 'Morningstart12']
# ghost_capi20: ['ghost_Capi20', 'ghost_capi20']
# x_artifex_x: ['x_ARTIFEX_x', 'x_Artifex_x', 'x_artifex_x']
# wanderer039: ['Wanderer039', 'wanderer039']
# mrfixit003: ['MrFixIt003', 'MrFixit003']
# kolyanskiy1: ['Kolyanskiy1', 'kolyanskiy1']
# djang0o_: ['Djang0o_', 'djang0o_']
# boudaxdd: ['boudaXDD', 'boudaxdd']
# pige0n98: ['PiGE0N98', 'pige0n98']
# sm0rc: ['SM0rc', 'sm0rc']
# frenzied701: ['FrenZied701', 'frenzied701']
# teodorvecerdi: ['TeodorVecerdi', 'teodorvecerdi']
# maoozkhan120: ['MaoozKhan120', 'maoozkhan120']
# honey2d: ['Honey2D', 'honey2D']
# farshidfff: ['Farshidfff', 'farshidfff']
# 4lreal: ['4lReal', '4lreal']
# n0rth0m: ['N0rth0M', 'n0rth0m']
# rooster6985: ['RoosTer6985', 'rooster6985']
# prizeey: ['Prizeey', 'prizeey']
# simplifiedbowl: ['SimplifiedBowl', 'simplifiedbowl']
# kz_azazejlb_06: ['KZ_AzAzeJlb_06', 'kz_azazejlb_06']
# carylo: ['Carylo', 'carylo']
# imstar1x: ['IMSTAR1X', 'imstar1x']
# rmnnpc: ['RmnNpc', 'rmnnpc']
# roxytr: ['RoxyTR', 'roxytr']
# lobotoomik: ['Lobotoomik', 'lobotoomik']
# dash_2600: ['DASH_2600', 'dash_2600']
# aireea: ['AireeA', 'aireea']
# sensekidd: ['SenseKidd', 'sensekidd']
# strongproflt: ['STRONGPROFlT', 'strongproflt']
# nirwanai: ['Nirwanai', 'nirwanai']
# pr4ks_cs2: ['pr4Ks_cs2', 'pr4ks_cs2']
# pinhajoga: ['PINHAjoga', 'pinhajoga']
# landaqq: ['LandaQQ', 'landaQQ', 'landaqq']
# zoddx47: ['Zoddx47', 'zoddx47']
# ithinkthereforeidrink: ['iThinkTHEREFOREiDrink', 'iThinkThereforeiDrink']
# 1mayas_ggz: ['1MAYAS_GGZ', '1MAYAS_GGz']
# 1tapelite_yugen: ['1TapElite_YUGEN', '1TapElite_YugeN']
# whitetrashdigital: ['WhiteTrashDigital', 'whitetrashdigital']
# al0ushii: ['AL0USHII', 'al0ushii']
# kenzokent: ['KenzoKent', 'kenzokent']
# kalzi0n: ['Kalzi0n', 'kAlZi0N']
# zriffty: ['Zriffty', 'zriffty']
# 7atc: ['7ATC', '7atc']
# zreez_angel: ['zReeZ_Angel', 'zreez_angel']
# schopfer_: ['SchopfeR_', 'Schopfer_']
# marmormaze: ['MARMORMAZE', 'Marmormaze']
# psycox777: ['PsYcOx777', 'psycox777']
# po20_04wali: ['Po20_04wali', 'po20_04wali']
# fl1nd3r: ['FL1ND3r', 'fl1nd3r']
# s4sk__: ['S4SK__', 's4sk__']
# vincentvonbroccoli: ['VincentVonBroccoli', 'vincentvonbroccoli']
# notoriousdiehard: ['NOToriousDiehard', 'NotoriousDiehard', 'notoriousdiehard']
# yocwilly: ['YoCWilly', 'yocwilly']
# one1_gamer: ['One1_gamer', 'one1_gamer']
# mysterohorsty: ['MysteroHorsty', 'mysterohorsty']
# spankerinooo: ['Spankerinooo', 'spankerinooo']
# momiiii69: ['Momiiii69', 'momiiii69']
# glexik_god: ['Glexik_God', 'glexik_god']
# wilisdex: ['WILISDEX', 'wilisDEX']
# batwick_: ['BATwick_', 'batwick_']
# shaffeeru786: ['shaffeeRU786', 'shaffeeru786']
# bevv_rayan: ['Bevv_Rayan', 'bevv_rayan']
# nabilallmighty: ['NabilAllMighty', 'Nabilallmighty']
# nomoresl: ['NoMoreSL', 'nomoresl']
# amirhaid: ['AmirHaid', 'amirhaid']
# cukululu41: ['cukuLuLu41', 'cukululu41']
# chillguy910: ['CHILLGUY910', 'chillguy910']
# magadesol: ['Magadesol', 'magadesol']
# night4slasher: ['Night4Slasher', 'night4slasher']
# illuminatistorm: ['IlluminatiStorm', 'Illuminatistorm']
# benxbari: ['BenXBari', 'benxbari']
# kofovica: ['kOfovicA', 'kofovica']
# ste_113: ['Ste_113', 'ste_113']
# aviatorgeeks: ['Aviatorgeeks', 'aviatorgeeks']
# winterwolf_audrey1234: ['winterwolf_Audrey1234', 'winterwolf_audrey1234']
# 1flusha: ['1Flusha', '1flusha']
# moonwolf0722: ['MOONWOLF0722', 'moonwolf0722']
# molluskfriend: ['MolluskFriend', 'molluskFriend']
# nightingale_______: ['Nightingale_______', 'nightingale_______']
# klaik92: ['kLaiK92', 'klaik92']
# lord______6: ['LORD______6', 'lord______6']
# dejmanoxd: ['dejmanoXD', 'dejmanoxd']
# l3sse_g: ['L3SSE_g', 'l3sse_g']
# anbugandhipoovai: ['AnbuGandhiPoovai', 'anbugandhipoovai']
# xnizol: ['xNizol', 'xnizol']
# gabork4: ['GaBoRk4', 'Gabork4']
# obada_almashni: ['Obada_almashni', 'obada_almashni']
# doniori1: ['DONIORI1', 'Doniori1']
# abdullahoneui: ['Abdullahoneui', 'abdullahoneui']
# gregg_69: ['Gregg_69', 'gregg_69']
# cho4otaco: ['CHO4oTacO', 'CHO4oTaco']
# dubsta5: ['Dubsta5', 'dubsta5']
# xtheghettogurketv: ['xTheGhettoGurkeTV', 'xtheghettogurketv']
# foooq: ['fOooQ', 'foooq']
# m0azzz: ['M0AZZZ', 'M0aZzz']
# cfu4y: ['CFU4Y', 'cfu4y']
# calumtooru: ['calumtoorU', 'calumtooru']
# cootfart: ['COOTFART', 'cootfart']
# davidchhakchhuak1017: ['DavidChhakchhuak1017', 'davidchhakchhuak1017']
# nilvandir: ['Nilvandir', 'nilvandir']
# cschomper: ['csCHOMPER', 'csChomper']
# redzaa0: ['redzAA0', 'redzaa0']
# ravmasau: ['ravmasAU', 'ravmasau']
# arriql: ['Arriql', 'arriql']
# fr0d0_gg: ['fr0d0_GG', 'fr0d0_gg']
# l1rth: ['L1RTH', 'l1rth']
# yusuf_mobra: ['YUSUF_MOBRA', 'Yusuf_Mobra']
# wnch5tr_: ['WNCH5TR_', 'wnch5tr_']
# xcleezo: ['xCleezO', 'xCleezo']
# carasque: ['carAsque', 'carasque']
# ap0stolos: ['Ap0stolos', 'ap0stolos']
# ljnlevi: ['LJNlevi', 'ljnlevi']
# toto_house: ['ToTo_house', 'toto_house']
# bootlegbonniee: ['BootlegBonniee', 'bootlegbonniee']
# ogbuda_szn: ['ogbuda_sZn', 'ogbuda_szn']
# alphaslanjr: ['AlphaslanJr', 'alphaslanjr']
# munkwh0: ['MunkWh0', 'munkwh0']
# jofferson015: ['Jofferson015', 'jofferson015']
# ousiacosmicbee: ['OusiaCosmicBee', 'ousiacosmicbee']
# itsedzz: ['ItsEdzZ', 'itsedzz']
# biti24: ['Biti24', 'biti24']
# honelanderbrute: ['HonelanderBrute', 'honelanderbrute']
# terminal4444: ['Terminal4444', 'terminal4444']
# huseyincsgoo: ['HuseyinCSGOO', 'huseyincsgoo']
# s3eed_098: ['S3eed_098', 's3eed_098']
# tbytkos: ['tBYtKOS', 'tbytkos']
# 7miyoshi7: ['7MIYOSHI7', '7miyoshi7']
# tisbect: ['Tisbect', 'tisbect']
# grigory: ['GRiGORY', 'grigory']
# wearbest: ['wearbesT', 'wearbest']
# enotkn: ['EnotKN', 'Enotkn']
# dveedo: ['DVEEDO', 'dveedo']
# forvidan: ['Forvidan', 'forvidan']
# kevlnyy: ['KEVlNYY', 'KEVlNYy']
# romadriftt: ['RomaDriftt', 'romadriftt']
# azaliaxox: ['Azaliaxox', 'azaliaxox']
# lagrettomentamozzo: ['LagrettoMentamozzo', 'lagrettomentamozzo']
# odren_: ['Odren_', 'odren_']
# salad_monkey: ['Salad_Monkey', 'Salad_monkey']
# glitchav: ['Glitchav', 'glitchav']
# dobrota1337game: ['Dobrota1337game', 'dobrota1337game']
# unknw0naccount: ['unknw0nAccount', 'unknw0naccount']
# clarkkent_7: ['ClarkKent_7', 'clarkkent_7']
# prime951__: ['Prime951__', 'prime951__']
# banditotheman: ['BanditoTheMan', 'banditotheman']
# bickcog158: ['BickCog158', 'bickcog158']
# pepegakun: ['PepegaKun', 'pepegakun']
# schiken44: ['SchiKen44', 'schiken44']
# d3on: ['D3ON', 'd3on']
# mishanyaa05: ['Mishanyaa05', 'mishanyaa05']
# yan1sq: ['Yan1sQ', 'yan1sq']
# bleekuwu: ['bleekUwU', 'bleekuwu']
# adam0f: ['Adam0f', 'adam0f']
# antidotdota_two: ['AntidotDota_Two', 'antidotdota_two']
# terapivip: ['TerapiVIP', 'terapivip']
# meteora38: ['Meteora38', 'meteora38']
# abdulbasit3454: ['Abdulbasit3454', 'abdulbasit3454']
# daaaaalx1: ['DAAAAALX1', 'daaaaalx1']
# nojokeee1: ['noJokeee1', 'nojokeee1']
# rotexenv3: ['Rotexenv3', 'rotexenv3']
# wallspritma: ['Wallspritma', 'wallspritma']
# maydenless: ['MAYDENLESS', 'maydenless']
# xpoll1: ['xPoLL1', 'xpoll1']
# man00war: ['MAN00WAR', 'Man00waR']
# blas1905: ['BLAS1905', 'Blas1905']
# magician7k: ['Magician7K', 'magician7k']
# primesquanchy: ['PrimeSquanchy', 'primesquanchy']
# chili_poe: ['Chili_poe', 'chili_PoE']
# ketamame: ['Ketamame', 'ketamame']
# sarvar78: ['Sarvar78', 'sarvar78']
# yonamex: ['Yonamex', 'yonamex']
# linkzerax: ['linkzeraX', 'linkzerax']
# infeisty: ['Infeisty', 'infeisty']
# theweekdie: ['Theweekdie', 'theweekdie']
# rafael_1912: ['Rafael_1912', 'rafael_1912']
# tagman3322: ['TagMan3322', 'tagman3322']
# giiigo_: ['Giiigo_', 'giiigo_']
# metnos: ['METNOS', 'metnos']
# 31lamemonster: ['31LameMonster', '31lamemonster']
# anxlwave: ['ANXLwave', 'anxlwave']
# creskg: ['CreskG', 'creskG']
# mautmaus: ['MauTMaus', 'mautmaus']
# long_t7: ['LONG_T7', 'Long_T7']
# cobainoff: ['COBAINoff', 'cobainoff']
# schlewel: ['schLEWEL', 'schlewel']
# iblatant: ['iBlatant', 'iblatant']
# zebekkk: ['Zebekkk', 'zebekkk']
# smartydolla: ['SmartyDolla', 'smartydolla']
# night_dukepl: ['Night_DukePL', 'night_dukepl']
# jean_tejada: ['Jean_Tejada', 'jean_tejada']
# 4widzewlodz: ['4Widzewlodz', '4widzewlodz']
# mergerette: ['Mergerette', 'mergerette']
# nat__1__ko: ['Nat__1__ko', 'nat__1__ko']
# topdogstef: ['TopDogStef', 'topdogstef']
# geiazou: ['Geiazou', 'geiazou']
# titisoul: ['Titisoul', 'titisoul']
# l3engie: ['l3ENGiE', 'l3engie']
# callmar11: ['Callmar11', 'callmar11']
# nov2x: ['Nov2x', 'nov2x']
# aili_tv: ['Aili_TV', 'Aili_tv', 'aili_tv']
# i_onsra: ['i_Onsra', 'i_onsra']
# keemur1: ['Keemur1', 'keemur1']
# realfeja: ['REALFEJA', 'realfeja']
# mrrobotone1: ['MrRobotOne1', 'mrrobotone1']
# hitmarkerino: ['HitMarkerino', 'hitmarkerino']
# shorty_020: ['Shorty_020', 'shorty_020']
# fivees__: ['Fivees__', 'fivees__']
# avinash023: ['Avinash023', 'avinash023']
# guffy0001: ['Guffy0001', 'guffy0001']
# asyousayy: ['ASYOUSAYY', 'asyousayy']
# brucewayne2211: ['BruceWayne2211', 'brucewayne2211']
# latviannoob321: ['Latviannoob321', 'latviannoob321']
# klarven_bro: ['Klarven_bro', 'klarven_bro']

# %%
# Create a mapping from all variants to the canonical (sorted first) variant
variant_map = {}
for variants in duplicate_users.values():
    sorted_variants = sorted(variants)
    canonical = sorted_variants[0]
    for v in variants:
        variant_map[v] = canonical

# Replace usernames in 'user' column
data['user'] = data['user'].apply(lambda u: variant_map.get(u, u))

# %%
# Convert 'date' to string for JSON serialization
data["date"] = data["date"].astype(str)

# Drop 'date_str' if it exists
if 'date_str' in data.columns:
    data = data.drop(columns=['date_str'])

# Reset index to get message IDs (0,1,2,...)
data = data.reset_index(drop=True)

# Create messages dict WITHOUT 'stream'
messages = data.drop(columns=['stream']).to_dict(orient="index")

# Create stream summary: first and last message ID per stream
stream_summary = {}
for stream_id in data['stream'].unique():
    stream_data = data[data['stream'] == stream_id]
    first_id = stream_data.index.min()
    last_id = stream_data.index.max()
    stream_summary[int(stream_id)] = {
        "first_message_id": int(first_id),
        "last_message_id": int(last_id)
    }

# Combine into final JSON structure
final_json = {
    "messages": messages,
    "streams": stream_summary
}

# Save as JSON
with open("data.json", "w") as f:
    json.dump(final_json, f, indent=2)

print("JSON file created with message data and stream summary.")
# Out:
# JSON file created with message data and stream summary.
